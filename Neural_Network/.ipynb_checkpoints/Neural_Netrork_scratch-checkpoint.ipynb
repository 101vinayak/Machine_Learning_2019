# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_circles

# %%
def accuracy(y_pred,y_act):  ## y_pred is the y cap in the formula
    return (100.0*np.sum(y_pred==y_act)/y_act.shape[0])

# %%
def softmax(a):  ## a vector a
    
    e_pa = np.exp(a)
    ans = e_pa/np.sum(e_pa,axis = 1,keepdims=True)  ## adding the sum along the col
    
    return ans

# %%
def loss(y_hot,p):     
    
    l = -np.mean(y_hot*np.log(p))
    return l

# %%
def one_hot(y,depth):  ## depth is no. of classes
    
    m = y.shape[0]
    y_out = np.zeros((m,depth))
    y_out[np.arange(m),y] = 1  ## the one that matches with y is 1
    
    return y_out

# %% [markdown]
# ## Making A Simple NN from random data

# %%
X,y = make_circles(n_samples=500,shuffle=True,noise=0.05,random_state=1,factor=0.8)

# %%
plt.style.use('seaborn')
plt.scatter(X[:,0],X[:,1],c=y,cmap=plt.cm.Accent)
plt.show()

# %%
input_size = 2
layers = [4,3]
output = 2

# %%
class NeuralNetwork:
    
    def __init__(self,Inp,layers,Out):
        
        np.random.seed(0)
    
        model = {}
        model["w1"] = np.random.randn(Inp,layers[0])/np.sqrt(Inp)
        model["b1"] = np.zeros((1,layers[0]))
        model["w2"] = np.random.randn(layers[0],layers[1])/np.sqrt(layers[0])
        model["b2"] = np.zeros((1,layers[1]))
        model["w3"] = np.random.randn(layers[1],Out)/np.sqrt(layers[1])
        model["b3"] = np.zeros((1,Out))
    
        self.model = model
        
    def forward_prop(self,X):
        
        z1 = X.dot(self.model["w1"] + self.model["b1"])
        a1 = np.tanh(z1)
        z2 = a1.dot(self.model["w2"] + self.model["b2"])
        a2 = np.tanh(z2)
        z3 = a2.dot(self.model["w3"] + self.model["b3"])
        y_out = softmax(z3)          ## a3 is the y cap
        
        self.act_vals = (a1,a2,y_out)
        return y_out
        
    def backward_prop(self,X,y,LR=0.00001):
        
        a1,a2,y_out = self.act_vals
        
        delta3 = y_out - y
        m = X.shape[0]  #3 no. of ex
    
        ## all are backtracking formulas
    
        dw3 = np.dot(a2.T,delta3)
        db3 = np.sum(delta3, axis=0)/float(m)
    
        delta2 = (1 - np.square(a2))*np.dot(delta3,self.model["w3"].T)
        dw2 = np.dot(a1.T,delta2)
        db2 = np.sum(delta2,axis=0)/float(m)
    
        delta1 = (1-np.square(a1))*np.dot(delta2,self.model["w2"].T)
        dw1 = np.dot(X.T,delta1)
        db1 = np.sum(delta1,axis=0)/float(m)
    
        self.model["w3"] -= LR*dw3
        self.model["b3"] -= LR*db3
        self.model["w2"] -= LR*dw2
        self.model["b2"] -= LR*db2
        self.model["w1"] -= LR*dw1
        self.model["b1"] -= LR*db1
    
        return model
    
    def predict(self,X):
        
        y_out = self.forward_prop(X)
        return np.argmax(y_out,axis=1)
    
    def summary(self):   ## to give a sumary if sizes of the hidden layers
    
        a1,a2,y_out = self.act_vals
        
        print("w1",self.model["w1"].shape)
        print("a1",a1.shape)

        print("w2",self.model["w2"].shape)
        print("a2",a2.shape)

        print("w3",self.model["w1"].shape)
        print("y_out",y_out.shape)

# %%
model = NeuralNetwork(Inp=2,layers=[4,3],Out=2)

# %%
model.forward_prop(X)
# Out:
# array([[0.80382886, 0.19617114],
#        [0.72541813, 0.27458187],
#        [0.81205637, 0.18794363],
#        [0.83023222, 0.16976778],
#        [0.3743681 , 0.6256319 ],
#        [0.48096635, 0.51903365],
#        [0.80659093, 0.19340907],
#        [0.76381136, 0.23618864],
#        [0.55514237, 0.44485763],
#        [0.75951556, 0.24048444],
#        [0.80711688, 0.19288312],
#        [0.1947435 , 0.8052565 ],
#        [0.49459009, 0.50540991],
#        [0.84257332, 0.15742668],
#        [0.80391794, 0.19608206],
#        [0.14682008, 0.85317992],
#        [0.20758583, 0.79241417],
#        [0.74522505, 0.25477495],
#        [0.28871587, 0.71128413],
#        [0.27934985, 0.72065015],
#        [0.77291385, 0.22708615],
#        [0.80150898, 0.19849102],
#        [0.78550821, 0.21449179],
#        [0.48487597, 0.51512403],
#        [0.83945993, 0.16054007],
#        [0.42091654, 0.57908346],
#        [0.76034088, 0.23965912],
#        [0.69241184, 0.30758816],
#        [0.17940695, 0.82059305],
#        [0.18963594, 0.81036406],
#        [0.16696386, 0.83303614],
#        [0.79644535, 0.20355465],
#        [0.4415636 , 0.5584364 ],
#        [0.19918169, 0.80081831],
#        [0.7140138 , 0.2859862 ],
#        [0.40564615, 0.59435385],
#        [0.74398465, 0.25601535],
#        [0.62124722, 0.37875278],
#        [0.28033664, 0.71966336],
#        [0.57769619, 0.42230381],
#        [0.79221007, 0.20778993],
#        [0.21003901, 0.78996099],
#        [0.28458941, 0.71541059],
#        [0.22447274, 0.77552726],
#        [0.79196252, 0.20803748],
#        [0.78403659, 0.21596341],
#        [0.78214555, 0.21785445],
#        [0.24902183, 0.75097817],
#        [0.26780154, 0.73219846],
#        [0.67784774, 0.32215226],
#        [0.20686958, 0.79313042],
#        [0.27172382, 0.72827618],
#        [0.64897876, 0.35102124],
#        [0.22581801, 0.77418199],
#        [0.1996227 , 0.8003773 ],
#        [0.82397367, 0.17602633],
#        [0.76277172, 0.23722828],
#        [0.78687836, 0.21312164],
#        [0.71429933, 0.28570067],
#        [0.64433699, 0.35566301],
#        [0.65180026, 0.34819974],
#        [0.79254369, 0.20745631],
#        [0.62923858, 0.37076142],
#        [0.4987621 , 0.5012379 ],
#        [0.37545085, 0.62454915],
#        [0.79224637, 0.20775363],
#        [0.32184375, 0.67815625],
#        [0.71932731, 0.28067269],
#        [0.74842227, 0.25157773],
#        [0.22389754, 0.77610246],
#        [0.78671636, 0.21328364],
#        [0.80106504, 0.19893496],
#        [0.27357824, 0.72642176],
#        [0.74820932, 0.25179068],
#        [0.55944141, 0.44055859],
#        [0.28756476, 0.71243524],
#        [0.54237822, 0.45762178],
#        [0.19215869, 0.80784131],
#        [0.58374971, 0.41625029],
#        [0.33167413, 0.66832587],
#        [0.64187547, 0.35812453],
#        [0.48325997, 0.51674003],
#        [0.17895294, 0.82104706],
#        [0.24512624, 0.75487376],
#        [0.20153747, 0.79846253],
#        [0.33072995, 0.66927005],
#        [0.20528462, 0.79471538],
#        [0.74826886, 0.25173114],
#        [0.5165734 , 0.4834266 ],
#        [0.40025517, 0.59974483],
#        [0.36801468, 0.63198532],
#        [0.38193407, 0.61806593],
#        [0.23483533, 0.76516467],
#        [0.63637974, 0.36362026],
#        [0.20180046, 0.79819954],
#        [0.68579711, 0.31420289],
#        [0.15626149, 0.84373851],
#        [0.73894442, 0.26105558],
#        [0.28327665, 0.71672335],
#        [0.55073718, 0.44926282],
#        [0.46051023, 0.53948977],
#        [0.17812155, 0.82187845],
#        [0.35862355, 0.64137645],
#        [0.8370736 , 0.1629264 ],
#        [0.39630891, 0.60369109],
#        [0.8369364 , 0.1630636 ],
#        [0.43731123, 0.56268877],
#        [0.55475396, 0.44524604],
#        [0.20245474, 0.79754526],
#        [0.6346343 , 0.3653657 ],
#        [0.71950716, 0.28049284],
#        [0.33167099, 0.66832901],
#        [0.21087406, 0.78912594],
#        [0.4693371 , 0.5306629 ],
#        [0.61672321, 0.38327679],
#        [0.17164576, 0.82835424],
#        [0.19520115, 0.80479885],
#        [0.70542537, 0.29457463],
#        [0.79866114, 0.20133886],
#        [0.22373307, 0.77626693],
#        [0.2939675 , 0.7060325 ],
#        [0.80029767, 0.19970233],
#        [0.20918025, 0.79081975],
#        [0.74525028, 0.25474972],
#        [0.3743449 , 0.6256551 ],
#        [0.7685648 , 0.2314352 ],
#        [0.56174239, 0.43825761],
#        [0.73627387, 0.26372613],
#        [0.82936954, 0.17063046],
#        [0.80837743, 0.19162257],
#        [0.20703835, 0.79296165],
#        [0.74112202, 0.25887798],
#        [0.20407111, 0.79592889],
#        [0.82649118, 0.17350882],
#        [0.43678215, 0.56321785],
#        [0.79807323, 0.20192677],
#        [0.20285397, 0.79714603],
#        [0.21306969, 0.78693031],
#        [0.42379025, 0.57620975],
#        [0.36476351, 0.63523649],
#        [0.30330878, 0.69669122],
#        [0.58882751, 0.41117249],
#        [0.41423009, 0.58576991],
#        [0.7593226 , 0.2406774 ],
#        [0.17980821, 0.82019179],
#        [0.77498569, 0.22501431],
#        [0.16140028, 0.83859972],
#        [0.70567418, 0.29432582],
#        [0.43718989, 0.56281011],
#        [0.72628846, 0.27371154],
#        [0.67159833, 0.32840167],
#        [0.84578465, 0.15421535],
#        [0.77764386, 0.22235614],
#        [0.7976988 , 0.2023012 ],
#        [0.59492815, 0.40507185],
#        [0.58134628, 0.41865372],
#        [0.47730586, 0.52269414],
#        [0.18908394, 0.81091606],
#        [0.67460622, 0.32539378],
#        [0.77805939, 0.22194061],
#        [0.54609212, 0.45390788],
#        [0.68892254, 0.31107746],
#        [0.40561221, 0.59438779],
#        [0.73667799, 0.26332201],
#        [0.20722825, 0.79277175],
#        [0.68110123, 0.31889877],
#        [0.40531358, 0.59468642],
#        [0.79164255, 0.20835745],
#        [0.26489564, 0.73510436],
#        [0.67464721, 0.32535279],
#        [0.74959463, 0.25040537],
#        [0.75919487, 0.24080513],
#        [0.34790534, 0.65209466],
#        [0.83225819, 0.16774181],
#        [0.16215806, 0.83784194],
#        [0.18263805, 0.81736195],
#        [0.21238201, 0.78761799],
#        [0.84568339, 0.15431661],
#        [0.23573636, 0.76426364],
#        [0.72610333, 0.27389667],
#        [0.678807  , 0.321193  ],
#        [0.22092768, 0.77907232],
#        [0.40405777, 0.59594223],
#        [0.4076125 , 0.5923875 ],
#        [0.45940657, 0.54059343],
#        [0.73254514, 0.26745486],
#        [0.82968363, 0.17031637],
#        [0.45923022, 0.54076978],
#        [0.66470194, 0.33529806],
#        [0.36094638, 0.63905362],
#        [0.33528607, 0.66471393],
#        [0.456455  , 0.543545  ],
#        [0.56641215, 0.43358785],
#        [0.80115498, 0.19884502],
#        [0.24311263, 0.75688737],
#        [0.49707918, 0.50292082],
#        [0.1610802 , 0.8389198 ],
#        [0.64190746, 0.35809254],
#        [0.37445636, 0.62554364],
#        [0.26081796, 0.73918204],
#        [0.44844511, 0.55155489],
#        [0.21686572, 0.78313428],
#        [0.71359947, 0.28640053],
#        [0.21647828, 0.78352172],
#        [0.77029989, 0.22970011],
#        [0.28639984, 0.71360016],
#        [0.36075841, 0.63924159],
#        [0.43235117, 0.56764883],
#        [0.18405596, 0.81594404],
#        [0.23462185, 0.76537815],
#        [0.17272852, 0.82727148],
#        [0.69384405, 0.30615595],
#        [0.29192071, 0.70807929],
#        [0.53002302, 0.46997698],
#        [0.39241523, 0.60758477],
#        [0.30882906, 0.69117094],
#        [0.55328659, 0.44671341],
#        [0.82875475, 0.17124525],
#        [0.58581281, 0.41418719],
#        [0.67675051, 0.32324949],
#        [0.72752034, 0.27247966],
#        [0.70403218, 0.29596782],
#        [0.19078181, 0.80921819],
#        [0.59402211, 0.40597789],
#        [0.68642184, 0.31357816],
#        [0.57161419, 0.42838581],
#        [0.70616438, 0.29383562],
#        [0.29787187, 0.70212813],
#        [0.38616695, 0.61383305],
#        [0.18650021, 0.81349979],
#        [0.22831923, 0.77168077],
#        [0.8327115 , 0.1672885 ],
#        [0.81193612, 0.18806388],
#        [0.69217647, 0.30782353],
#        [0.17641074, 0.82358926],
#        [0.78597209, 0.21402791],
#        [0.26371949, 0.73628051],
#        [0.78529856, 0.21470144],
#        [0.20491033, 0.79508967],
#        [0.2264806 , 0.7735194 ],
#        [0.18698991, 0.81301009],
#        [0.53275401, 0.46724599],
#        [0.1909985 , 0.8090015 ],
#        [0.16955688, 0.83044312],
#        [0.19617197, 0.80382803],
#        [0.3319891 , 0.6680109 ],
#        [0.2938466 , 0.7061534 ],
#        [0.7189886 , 0.2810114 ],
#        [0.21972004, 0.78027996],
#        [0.3183299 , 0.6816701 ],
#        [0.66871915, 0.33128085],
#        [0.53223109, 0.46776891],
#        [0.7834427 , 0.2165573 ],
#        [0.212577  , 0.787423  ],
#        [0.19259617, 0.80740383],
#        [0.40081576, 0.59918424],
#        [0.20794907, 0.79205093],
#        [0.26553943, 0.73446057],
#        [0.78351259, 0.21648741],
#        [0.19270071, 0.80729929],
#        [0.23574191, 0.76425809],
#        [0.5526038 , 0.4473962 ],
#        [0.36425144, 0.63574856],
#        [0.38859368, 0.61140632],
#        [0.33379068, 0.66620932],
#        [0.66666887, 0.33333113],
#        [0.27791835, 0.72208165],
#        [0.45151699, 0.54848301],
#        [0.75386596, 0.24613404],
#        [0.41600043, 0.58399957],
#        [0.20955706, 0.79044294],
#        [0.45808624, 0.54191376],
#        [0.24344219, 0.75655781],
#        [0.24964035, 0.75035965],
#        [0.64617213, 0.35382787],
#        [0.19599422, 0.80400578],
#        [0.80960237, 0.19039763],
#        [0.38108297, 0.61891703],
#        [0.59189915, 0.40810085],
#        [0.81862881, 0.18137119],
#        [0.72056446, 0.27943554],
#        [0.80946264, 0.19053736],
#        [0.79734693, 0.20265307],
#        [0.64338412, 0.35661588],
#        [0.51294549, 0.48705451],
#        [0.3045467 , 0.6954533 ],
#        [0.809773  , 0.190227  ],
#        [0.5811428 , 0.4188572 ],
#        [0.53473719, 0.46526281],
#        [0.25464233, 0.74535767],
#        [0.83524701, 0.16475299],
#        [0.81138512, 0.18861488],
#        [0.27969501, 0.72030499],
#        [0.23243048, 0.76756952],
#        [0.24800632, 0.75199368],
#        [0.56964078, 0.43035922],
#        [0.31380656, 0.68619344],
#        [0.2988569 , 0.7011431 ],
#        [0.29043829, 0.70956171],
#        [0.56059333, 0.43940667],
#        [0.61074969, 0.38925031],
#        [0.73479487, 0.26520513],
#        [0.16628626, 0.83371374],
#        [0.74269367, 0.25730633],
#        [0.3153111 , 0.6846889 ],
#        [0.48425871, 0.51574129],
#        [0.83425737, 0.16574263],
#        [0.23414971, 0.76585029],
#        [0.37048908, 0.62951092],
#        [0.27629963, 0.72370037],
#        [0.18780437, 0.81219563],
#        [0.75813631, 0.24186369],
#        [0.38041353, 0.61958647],
#        [0.18417807, 0.81582193],
#        [0.34770517, 0.65229483],
#        [0.59562989, 0.40437011],
#        [0.82384104, 0.17615896],
#        [0.30321339, 0.69678661],
#        [0.46034809, 0.53965191],
#        [0.78672217, 0.21327783]])

# %%
model.summary()
# Out:
# w1 (2, 4)
# a1 (500, 4)
# w2 (4, 3)
# a2 (500, 3)
# w3 (2, 4)
# y_out (500, 2)

# %%
def train(X,y,model,epochs,LR,logs=True):
    
    training_loss = []
    classes = 2
    
    y_hot = one_hot(y,classes)
    
    for ix in range(epochs):
        
        y_out = model.forward_prop(X)
        l = loss(y_hot,y_out)
        model.backward_prop(X,y_hot,LR)
        
        if logs:
            print("Epoch %d loss %.4f"%(ix,l))
            
        training_loss.append(l)
            
    return training_loss

# %%
_Loss = train(X,y,model,500,0.01)
# Out:
# Epoch 0 loss 0.4136
# Epoch 1 loss 0.6405
# Epoch 2 loss 0.3709
# Epoch 3 loss 0.6884
# Epoch 4 loss 0.4072
# Epoch 5 loss 0.7423
# Epoch 6 loss 0.6532
# Epoch 7 loss 0.3711
# Epoch 8 loss 0.5430
# Epoch 9 loss 0.3581
# Epoch 10 loss 0.4213
# Epoch 11 loss 0.4923
# Epoch 12 loss 0.3557
# Epoch 13 loss 0.3466
# Epoch 14 loss 0.3466
# Epoch 15 loss 0.3466
# Epoch 16 loss 0.3466
# Epoch 17 loss 0.3466
# Epoch 18 loss 0.3466
# Epoch 19 loss 0.3466
# Epoch 20 loss 0.3466
# Epoch 408 loss 0.3466
# Epoch 409 loss 0.3466
# Epoch 410 loss 0.3466
# Epoch 411 loss 0.3466
# Epoch 412 loss 0.3466
# Epoch 413 loss 0.3466
# Epoch 414 loss 0.3466
# Epoch 415 loss 0.3466
# Epoch 416 loss 0.3466
# Epoch 417 loss 0.3466
# Epoch 418 loss 0.3466
# Epoch 419 loss 0.3466
# Epoch 420 loss 0.3466
# Epoch 421 loss 0.3466
# Epoch 422 loss 0.3466
# Epoch 423 loss 0.3466
# Epoch 424 loss 0.3466
# Epoch 425 loss 0.3466
# Epoch 426 loss 0.3466
# Epoch 427 loss 0.3466
# Epoch 428 loss 0.3466
# Epoch 429 loss 0.3466
# Epoch 430 loss 0.3466
# Epoch 431 loss 0.3466
# Epoch 432 loss 0.3466
# Epoch 433 loss 0.3466
# Epoch 434 loss 0.3466
# Epoch 435 loss 0.3466
# Epoch 436 loss 0.3466
# Epoch 437 loss 0.3466
# Epoch 438 loss 0.3466
# Epoch 439 loss 0.3466
# Epoch 440 loss 0.3466
# Epoch 441 loss 0.3466
# Epoch 442 loss 0.3466
# Epoch 443 loss 0.3466
# Epoch 444 loss 0.3466
# Epoch 445 loss 0.3466
# Epoch 446 loss 0.3466
# Epoch 447 loss 0.3466
# Epoch 448 loss 0.3466
# Epoch 449 loss 0.3466
# Epoch 450 loss 0.3466
# Epoch 451 loss 0.3466
# Epoch 452 loss 0.3466
# Epoch 453 loss 0.3466
# Epoch 454 loss 0.3466
# Epoch 455 loss 0.3466
# Epoch 456 loss 0.3466
# Epoch 457 loss 0.3466
# Epoch 458 loss 0.3466
# Epoch 459 loss 0.3466
# Epoch 460 loss 0.3466
# Epoch 461 loss 0.3466
# Epoch 462 loss 0.3466
# Epoch 463 loss 0.3466
# Epoch 464 loss 0.3466
# Epoch 465 loss 0.3466
# Epoch 466 loss 0.3466
# Epoch 467 loss 0.3466
# Epoch 468 loss 0.3466
# Epoch 469 loss 0.3466
# Epoch 470 loss 0.3466
# Epoch 471 loss 0.3466
# Epoch 472 loss 0.3466
# Epoch 473 loss 0.3466
# Epoch 474 loss 0.3466
# Epoch 475 loss 0.3466
# Epoch 476 loss 0.3466
# Epoch 477 loss 0.3466
# Epoch 478 loss 0.3466
# Epoch 479 loss 0.3466
# Epoch 480 loss 0.3466
# Epoch 481 loss 0.3466
# Epoch 482 loss 0.3466
# Epoch 483 loss 0.3466
# Epoch 484 loss 0.3466
# Epoch 485 loss 0.3466
# Epoch 486 loss 0.3466
# Epoch 487 loss 0.3466
# Epoch 488 loss 0.3466
# Epoch 489 loss 0.3466
# Epoch 490 loss 0.3466
# Epoch 491 loss 0.3466
# Epoch 492 loss 0.3466
# Epoch 493 loss 0.3466
# Epoch 494 loss 0.3466
# Epoch 495 loss 0.3466
# Epoch 496 loss 0.3466
# Epoch 497 loss 0.3466
# Epoch 498 loss 0.3466
# Epoch 499 loss 0.3466

# %%
plt.plot(_Loss)

# %%
from reg_util
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-fa392344aab0> in <module>
# ----> 1 from pylib.plot import plot_decision_boundary
#
# ImportError: No module named 'pylib'
